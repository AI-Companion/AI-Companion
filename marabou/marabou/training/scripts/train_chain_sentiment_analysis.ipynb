# %% [markdown]
# ## Clone repo and run training script

# %%
import os
! git clone -b refactor_code https://github.com/AI-Companion/AI-Companion.git
os.environ['PYTHONPATH'] += ":/content/AI-Companion/marabou/"
# Out:
# Cloning into 'AI-Companion'...
# remote: Enumerating objects: 635, done.
# remote: Counting objects: 100% (635/635), done.
# remote: Compressing objects: 100% (420/420), done.
# remote: Total 11408 (delta 381), reused 447 (delta 208), pack-reused 10773
# Receiving objects: 100% (11408/11408), 97.59 MiB | 23.68 MiB/s, done.
# Resolving deltas: 100% (4257/4257), done.

# %%
! python AI-Companion/marabou/marabou/training/scripts/train_sentiment_analysis.py
# Out:
# 2021-03-14 14:16:07.852372: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-03-14 14:16:10.558987: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2021-03-14 14:16:10.697011: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2021-03-14 14:16:10.825688: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2021-03-14 14:16:10.958319: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# ...

# %%
# !zip -r /content/sentiment_analysis_tfidf_model.zip AI-Companion/marabou/saved_models/
# Out:
#   adding: AI-Companion/marabou/saved_models/ (stored 0%)
#   adding: AI-Companion/marabou/saved_models/tfidf.png (deflated 10%)
#   adding: AI-Companion/marabou/saved_models/readme.txt (deflated 8%)
#   adding: AI-Companion/marabou/saved_models/tfidf/ (stored 0%)
#   adding: AI-Companion/marabou/saved_models/tfidf/saved_model.pb (deflated 91%)
#   adding: AI-Companion/marabou/saved_models/tfidf/assets/ (stored 0%)
#   adding: AI-Companion/marabou/saved_models/tfidf/variables/ (stored 0%)
#   adding: AI-Companion/marabou/saved_models/tfidf/variables/variables.data-00000-of-00001 (deflated 40%)
#   adding: AI-Companion/marabou/saved_models/tfidf/variables/variables.index (deflated 54%)
